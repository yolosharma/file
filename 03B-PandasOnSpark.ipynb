# %% [markdown]
# ####PandasOnSpark -- Nifty.csv

# %%
# import pandas for spark

# %%
# reade file nifty.csv

# %%
# display row & col count

# %%
# display column Names

# %%
# display data type of each column

# %%
# print dataframe

# %%
# show dataframe metadat / structure / info

# %%
# display top 5 columns

# %%
# display 5 point summary, count, mean & std of all numeric items

# %%
# display summary info of column "Sector" & "SecurityName"

# %%
# display count of records in dataframe

# %%
# display count of unique records in dataframe based "Symbol"

# %%
# dispaly the number of rows in each "Sector"

# %%
# dispaly the total "Trades" for each "SecurityName"

# %%
# dispaly the average "ClosePrice" for each "SecurityName"

# %%
# dispaly the minimum "TradeQty" for each "SecurityName"

# %%
# dispaly the maximum "TradeValue" for each "SecurityName"

# %%
# create new dataframe containing all rows of "Auto" in "Sector"

# %%
# create new dataframe containing all rows of "Auto" or "Cement" in "Sector"

# %%
# create new dataframe containing all rows of "ClosePrice" >= 1000

# %%
# display count rowsof all where "ClosePrice" >= 1000

# %%
# create new dataframe containing all rows of "ClosePrice" >= 1000 and "OpenPrice" >= 1000

# %%
# display count rowsof all where "ClosePrice" >= 1000 and "OpenPrice" >= 1000

# %%
# add column a new column (column name your choice) with default value (valur your choice)

# %%
# drop the column created above

# %%
# create new column "GoL" value containg "ClosePrice" less "PrevColse"

# %%
# Create new column "GoL-Label" value GoL > 0 then "Gain", GoL < 0 then "Loss", GoL = 0 then "Zero"

# %%
# using for loop display "Sector", "Symbol", "GoL" and GoL-Label

# %%
# create a new dataframe containg all rows starting with "TATA", command should be case insensitive

# %%
# create a new dataframe containg all rows ending with "LTD", command should be case insensitive

# %%
# create a new dataframe containg all rows containing "BANK", command should be case insensitive

# %%
# change data type of column "Trades" to float

# %%
# delete columns "Mkt" and "Series"

# %%
# rename column "SEcurityName" to "CompanyName"
